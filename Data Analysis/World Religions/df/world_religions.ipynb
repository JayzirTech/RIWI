# %%
import kagglehub
import os

path = kagglehub.dataset_download(
    "umichigan/world-religions"
)

print("Ruta:", path)

files = os.listdir(path)
print(f'\n"Archivos:", {files}')
# Out:
# Ruta: C:\Users\Coder\.cache\kagglehub\datasets\umichigan\world-religions\versions\1
#
# "Archivos:", ['global.csv', 'national.csv', 'regional.csv']

# %%
import pandas as pd

df_global = pd.read_csv(os.path.join(path, "global.csv"))

df_regional = pd.read_csv(os.path.join(path, "regional.csv"))

df_global

df_regional
# Out:
#     year     region  christianity_protestant  christianity_romancatholic  \
# 0   1945     Africa                  2074180                      672337
# 1   1945       Asia                  2407144                     2222908
# 2   1945     Europe                 83145512                   216041422
# 3   1945    Mideast                    87174                      635929
# 4   1945  West. Hem                 73173575                   171759439
# ..   ...        ...                      ...                         ...
# 65  2010     Africa                143752568                   165943467
# 66  2010       Asia                109770301                   129766537
# 67  2010     Europe                 65717165                   244246870
# 68  2010    Mideast                  2115645                     5126980
# 69  2010  West. Hem                236474406                   504625969
#
#     christianity_easternorthodox  christianity_anglican  christianity_other  \
# ...

# %%
#print(df_global.columns)

df_global.head(1)
# Out:
#    year  christianity_protestant  christianity_romancatholic  \
# 0  1945                160887585                   391332035
#
#    christianity_easternorthodox  christianity_anglican  christianity_other  \
# 0                      98501171               36955033            13674466
#
#    christianity_all  judaism_orthodox  judaism_conservative  judaism_reform  \
# 0         701350290            856827               1426350         1929388
#
#    ...  baha’i_percent  taoism_percent  jainism_percent  confucianism_percent  \
# 0  ...             0.0          0.0001              0.0                   0.0
#
#    syncretism_percent  animism_percent  noreligion_percent  \
# 0              0.2666           0.0207              0.0955
#
#    otherreligion_percent  religion_sumpercent  total_percent
# 0                 0.0061             1.012061       0.718667
#
# [1 rows x 76 columns]

# %%
#print(df_regional.columns)

df_regional.head(7)
# Out:
#    year     region  christianity_protestant  christianity_romancatholic  \
# 0  1945     Africa                  2074180                      672337
# 1  1945       Asia                  2407144                     2222908
# 2  1945     Europe                 83145512                   216041422
# 3  1945    Mideast                    87174                      635929
# 4  1945  West. Hem                 73173575                   171759439
# 5  1950     Africa                  3302860                      736193
# 6  1950       Asia                  9360004                    25948053
#
#    christianity_easternorthodox  christianity_anglican  christianity_other  \
# 0                       7251492                 419457             4170594
# 1                        181928                3142204             1964907
# 2                      86503645               29855595             5361826
# 3                       3180260                      0              108332
# ...

# %%
df_global = df_global.set_index('year')

df_christianity = df_global[['christianity_protestant', 'christianity_romancatholic', 'christianity_easternorthodox', 'christianity_anglican', 'christianity_other']]

df_judaism = df_global[['judaism_orthodox', 'judaism_conservative', 'judaism_reform', 'judaism_other']]

df_islam = df_global[['islam_sunni', 'islam_shi’a', 'islam_ibadhi', 'islam_nationofislam', 'islam_alawite', 'islam_ahmadiyya', 'islam_other']]

df_buddhism = df_global[['buddhism_mahayana', 'buddhism_theravada', 'buddhism_other']]

df_zoroastrianism = df_global[['zoroastrianism_all']]

df_hinduism = df_global[['hinduism_all']]

df_sikhism = df_global[['sikhism_all']]

df_shinto = df_global[['shinto_all']]

df_bahai = df_global[['baha’i_all']]

df_taoism = df_global[['taoism_all']]

df_jainism = df_global[['jainism_all']]

df_confucianism = df_global[['confucianism_all']]

df_syncretism = df_global[['syncretism_all']]

df_animism = df_global[['animism_all']]

df_noreligion = df_global[['noreligion_all']]

df_otherreligion = df_global[['otherreligion_all']]

# %%
'''from sqlalchemy import create_engine

import os
from dotenv import load_dotenv  

load_dotenv()

# 1. Configura los datos de conexión a tu base de datos PostgreSQL
# Estructura: postgresql+psycopg2://usuario:contraseña@host:puerto/nombre_base_datos
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")

# 2. Crear el motor (engine) de conexión
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db_name}")

# 3. Volcar todo el DataFrame a PostgreSQL
dff.to_sql(
    name="dataset",  # Nombre que tendrá la tabla en la base de datos
    con=engine,                 # El motor de conexión que creamos
    if_exists="replace",        # Opciones: 'fail' (falla si existe), 'replace' (reemplaza la tabla), 'append' (agrega filas)
    index=False,                # True si quieres guardar el índice del DataFrame como una columna
    chunksize=10000             # Recomendado para datasets grandes: inserta en bloques de 10,000 filas
)

print("¡DataFrame exportado exitosamente a PostgreSQL!")'''
# Out:
# 'from sqlalchemy import create_engine\n\nimport os\nfrom dotenv import load_dotenv  \n\nload_dotenv()\n\n# 1. Configura los datos de conexión a tu base de datos PostgreSQL\n# Estructura: postgresql+psycopg2://usuario:contraseña@host:puerto/nombre_base_datos\nuser = os.getenv("DB_USER")\npassword = os.getenv("DB_PASSWORD")\nhost = os.getenv("DB_HOST")\nport = os.getenv("DB_PORT")\ndb_name = os.getenv("DB_NAME")\n\n# 2. Crear el motor (engine) de conexión\nengine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db_name}")\n\n# 3. Volcar todo el DataFrame a PostgreSQL\ndff.to_sql(\n    name="dataset",  # Nombre que tendrá la tabla en la base de datos\n    con=engine,                 # El motor de conexión que creamos\n    if_exists="replace",        # Opciones: \'fail\' (falla si existe), \'replace\' (reemplaza la tabla), \'append\' (agrega filas)\n    index=False,                # True si quieres guardar el índice del DataFrame como una columna\n    chunksize=10
# ...

# %%
# Sumar solo las regiones del año 1945
suma_regiones_1945 = df_regional[df_regional['year'] == 1945][['christianity_protestant', 'christianity_romancatholic']].sum()
print("Suma de regiones 1945:\n", suma_regiones_1945)

print("\nValor en df_global para 1945:")
print(df_global[df_global['year'] == 1945][['christianity_protestant', 'christianity_romancatholic']])
# Out:
# Suma de regiones 1945:
#  christianity_protestant       160887585
# christianity_romancatholic    391332035
# dtype: int64
#
# Valor en df_global para 1945:
#    christianity_protestant  christianity_romancatholic
# 0                160887585                   391332035
