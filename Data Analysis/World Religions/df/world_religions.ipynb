# %%
import kagglehub
import os

path = kagglehub.dataset_download(
    "umichigan/world-religions"
)

print("Ruta:", path)

files = os.listdir(path)
print(f'\n"Archivos:", {files}')
# Out:
# Ruta: C:\Users\Coder\.cache\kagglehub\datasets\umichigan\world-religions\versions\1
#
# "Archivos:", ['global.csv', 'national.csv', 'regional.csv']

# %%
import pandas as pd

df = pd.read_csv(os.path.join(path, "global.csv"))

columnas = [
    "year",
    "christianity_all",
    "population",
    "religion_all",
    "world_population",
]
df[columnas].head()
# Out:
#    year  christianity_all  population  religion_all  world_population
# 0  1945         701350290  1617000000    1636502751        2250000000
# 1  1950         696480122  2231000000    2255911264        2780296616
# 2  1955         836002102  2536000000    2565905174        3039433944
# 3  1960         966967595  2921000000    2960719583        3345409879
# 4  1965        1074713786  3280000000    3302068346        3706601448

# %%
print(df.columns)
df.info()
df.isna().sum()
# Out:
# Index(['year', 'christianity_protestant', 'christianity_romancatholic',
#        'christianity_easternorthodox', 'christianity_anglican',
#        'christianity_other', 'christianity_all', 'judaism_orthodox',
#        'judaism_conservative', 'judaism_reform', 'judaism_other',
#        'judaism_all', 'islam_sunni', 'islam_shi’a', 'islam_ibadhi',
#        'islam_nationofislam', 'islam_alawite', 'islam_ahmadiyya',
#        'islam_other', 'islam_all', 'buddhism_mahayana', 'buddhism_theravada',
#        'buddhism_other', 'buddhism_all', 'zoroastrianism_all', 'hinduism_all',
#        'sikhism_all', 'shinto_all', 'baha’i_all', 'taoism_all', 'jainism_all',
#        'confucianism_all', 'syncretism_all', 'animism_all', 'noreligion_all',
#        'otherreligion_all', 'religion_all', 'population', 'world_population',
#        'protestant_percent', 'romancatholic_percent',
#        'easternorthodox_percent', 'anglican_percent',
#        'otherchristianity_percent', 'christianity_percent', 'orthodox_percent',
#        'conservative_percent', 'reform_percent', 'otherjudaism_percent',
#        'judaism_percent', 'sunni_percent', 'shi’a_percent', 'ibadhi_percent',
#        'nationofislam_percent', 'alawite_percent', 'ahmadiyya_percent',
#        'otherislam_percent', 'islam_percent', 'mahayana_percent',
#        'theravada_percent', 'otherbuddhism_percent', 'buddhism_percent',
#        'zoroastrianism_percent', 'hinduism_percent', 'sikhism_percent',
#        'shinto_percent', 'baha’i_percent', 'taoism_percent', 'jainism_percent',
#        'confucianism_percent', 'syncretism_percent', 'animism_percent',
#        'noreligion_percent', 'otherreligion_percent', 'religion_sumpercent',
#        'total_percent'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 76 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          14 non-null     int64
#  1   christianity_protestant       14 non-null     int64
#  2   christianity_romancatholic    14 non-null     int64
#  3   christianity_easternorthodox  14 non-null     int64
#  4   christianity_anglican         14 non-null     int64
#  5   christianity_other            14 non-null     int64
#  6   christianity_all              14 non-null     int64
#  7   judaism_orthodox              14 non-null     int64
#  8   judaism_conservative          14 non-null     int64
#  9   judaism_reform                14 non-null     int64
#  10  judaism_other                 14 non-null     int64
#  11  judaism_all                   14 non-null     int64
#  12  islam_sunni                   14 non-null     int64
#  13  islam_shi’a                   14 non-null     int64
#  14  islam_ibadhi                  14 non-null     int64
#  15  islam_nationofislam           14 non-null     int64
#  16  islam_alawite                 14 non-null     int64
#  17  islam_ahmadiyya               14 non-null     int64
#  18  islam_other                   14 non-null     int64
#  19  islam_all                     14 non-null     int64
#  20  buddhism_mahayana             14 non-null     int64
#  21  buddhism_theravada            14 non-null     int64
#  22  buddhism_other                14 non-null     int64
#  23  buddhism_all                  14 non-null     int64
#  24  zoroastrianism_all            14 non-null     int64
#  25  hinduism_all                  14 non-null     int64
#  26  sikhism_all                   14 non-null     int64
#  27  shinto_all                    14 non-null     int64
#  28  baha’i_all                    14 non-null     int64
#  29  taoism_all                    14 non-null     int64
#  30  jainism_all                   14 non-null     int64
#  31  confucianism_all              14 non-null     int64
#  32  syncretism_all                14 non-null     int64
#  33  animism_all                   14 non-null     int64
#  34  noreligion_all                14 non-null     int64
#  35  otherreligion_all             14 non-null     int64
#  36  religion_all                  14 non-null     int64
#  37  population                    14 non-null     int64
#  38  world_population              14 non-null     int64
#  39  protestant_percent            14 non-null     float64
#  40  romancatholic_percent         14 non-null     float64
#  41  easternorthodox_percent       14 non-null     float64
#  42  anglican_percent              14 non-null     float64
#  43  otherchristianity_percent     14 non-null     float64
#  44  christianity_percent          14 non-null     float64
#  45  orthodox_percent              14 non-null     float64
#  46  conservative_percent          14 non-null     float64
#  47  reform_percent                14 non-null     float64
#  48  otherjudaism_percent          14 non-null     float64
#  49  judaism_percent               14 non-null     float64
#  50  sunni_percent                 14 non-null     float64
#  51  shi’a_percent                 14 non-null     float64
#  52  ibadhi_percent                14 non-null     float64
#  53  nationofislam_percent         14 non-null     int64
#  54  alawite_percent               14 non-null     float64
#  55  ahmadiyya_percent             14 non-null     float64
#  56  otherislam_percent            14 non-null     float64
#  57  islam_percent                 14 non-null     float64
#  58  mahayana_percent              14 non-null     float64
#  59  theravada_percent             14 non-null     float64
#  60  otherbuddhism_percent         14 non-null     float64
#  61  buddhism_percent              14 non-null     float64
#  62  zoroastrianism_percent        14 non-null     float64
#  63  hinduism_percent              14 non-null     float64
#  64  sikhism_percent               14 non-null     float64
#  65  shinto_percent                14 non-null     float64
#  66  baha’i_percent                14 non-null     float64
#  67  taoism_percent                14 non-null     float64
#  68  jainism_percent               14 non-null     float64
#  69  confucianism_percent          14 non-null     float64
#  70  syncretism_percent            14 non-null     float64
#  71  animism_percent               14 non-null     float64
#  72  noreligion_percent            14 non-null     float64
#  73  otherreligion_percent         14 non-null     float64
#  74  religion_sumpercent           14 non-null     float64
#  75  total_percent                 14 non-null     float64
# dtypes: float64(36), int64(40)
# memory usage: 8.4 KB
# year                            0
# christianity_protestant         0
# christianity_romancatholic      0
# christianity_easternorthodox    0
# christianity_anglican           0
#                                ..
# animism_percent                 0
# noreligion_percent              0
# otherreligion_percent           0
# religion_sumpercent             0
# total_percent                   0
# Length: 76, dtype: int64

# %%
df = df[['year', 'christianity_protestant', 'christianity_romancatholic']]

# %%
from sqlalchemy import create_engine

# 1. Configura los datos de conexión a tu base de datos PostgreSQL
# Estructura: postgresql+psycopg2://usuario:contraseña@host:puerto/nombre_base_datos
usuario = "postgres"
password = "Jayzir18!"
host = "localhost"
port = "5432"
db_name = "diabetes_risk_prediction"

# 2. Crear el motor (engine) de conexión
engine = create_engine(f"postgresql+psycopg2://{usuario}:{password}@{host}:{port}/{db_name}")

# 3. Volcar todo el DataFrame a PostgreSQL
dff.to_sql(
    name="dataset",  # Nombre que tendrá la tabla en la base de datos
    con=engine,                 # El motor de conexión que creamos
    if_exists="replace",        # Opciones: 'fail' (falla si existe), 'replace' (reemplaza la tabla), 'append' (agrega filas)
    index=False,                # True si quieres guardar el índice del DataFrame como una columna
    chunksize=10000             # Recomendado para datasets grandes: inserta en bloques de 10,000 filas
)

print("¡DataFrame exportado exitosamente a PostgreSQL!")
# Out:
# ¡DataFrame exportado exitosamente a PostgreSQL!
